# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "promedio_de_examenes_cortos":[59,92,72,90,95,87,89,77,76,65,97,42,94,62,91],
    "promedio_final":[64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]
})
df
# Out:
#     promedio_de_examenes_cortos  promedio_final
# 0                            59              64
# 1                            92              84
# 2                            72              77
# 3                            90              80
# 4                            95              77
# 5                            87              81
# 6                            89              80
# 7                            77              84
# 8                            76              80
# 9                            65              69
# 10                           97              83
# 11                           42              40
# 12                           94              78
# 13                           62              65
# 14                           91              90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   promedio_de_examenes_cortos  15 non-null     int64
#  1   promedio_final               15 non-null     int64
# dtypes: int64(2)
# memory usage: 372.0 bytes

# %%
df.describe()
# Out:
#        promedio_de_examenes_cortos  promedio_final
# count                    15.000000       15.000000
# mean                     79.200000       75.466667
# std                      16.297239       12.123570
# min                      42.000000       40.000000
# 25%                      68.500000       73.000000
# 50%                      87.000000       80.000000
# 75%                      91.500000       82.000000
# max                      97.000000       90.000000

# %%
#1. establesca una variable dependiente (x) y una variable independiente (y)
x=df["promedio_de_examenes_cortos"]
y=df["promedio_final"]

# %%
#2. realice un diagrama de dispersion para estos datos
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="ausencias",
plt.xlabel("Promedio_de_examenes_cortos")
plt.ylabel("promedio_final")
plt.title("Promedio_de_examenes_cortos_vs_promedio_final")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-182/33490685.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
3. ¿Los datos soportan la suposición de linealidad? si

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y)
print(f"coeficiente de correlacion(r):{r:0.4f}"),
print(f"valor-p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion(r):0.8646
# valor-p:0.0000

# %%
#5. Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinacion:{r**2:0.4f}")
# Out:
# coeficiente de determinacion:0.7475

# %%
# 6. Obtenga la recta de regresión ajustada
#y grafíquelo sobre el gráfico de dispersión
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                          24.526822
# promedio_de_examenes_cortos     0.643180
# dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.scatter(x, y,
            color="blue",
            edgecolor="black",
            alpha=0.9,
            s=10,
            label="promedio_final")
plt.plot(x, y_calculada,
         color="red",
         linewidth=2.2,
         linestyle="-",
         marker="o",
         markersize=5,
         markerfacecolor="white",
         markeredgecolor="black",
         label="recta de regresión")
plt.title(
"recta_de_regresion_lineal_entre_Promedio_de_examenes_cortos_vs_promedio_final"
)
plt.xlabel("Promedio_de_examenes_cortos")
plt.ylabel("Promedio_final")
plt.legend()
plt.show()

# %%
#7. Obtenga un intervalo de confianza del 95% parala pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                     0          1
# const                        6.441997  42.611646
# promedio_de_examenes_cortos  0.419219   0.867141

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales=modelo.resid
#grafico de dispersion
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,residuales)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="residuales"
plt.plot(
    x,residuales,
    marker="o",
    color="red",
    linewidth=0,
    linestyle="",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="puntos_residuales"
    )
plt.xlabel("Promedio_de_examenes_cortos")
plt.ylabel("residuales")
plt.title("Promedio_de_examenes_cortos_vs_residuales")

plt.axhline(y=0,color="red",linestyle="--") #linea horizontal

# %% [markdown]
# por lo que podemos observar que si cumple con los supuestos

# %%
#9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor-p:{valor_p:0.4f}")
# Out:
# valor-p:0.9018

# %% [markdown]
# Como p > 0.05, no se rechaza H₀.
# Los residuales siguen distribución normal.

# %%
#10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.2289

# %% [markdown]
# Como p > 0.05, no se rechaza H₀.
# Hay homocedasticidad.

# %%
#11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de
#regresión ajustada,¿cuáles son los resultados esperados para estos tres alumnos?
# f(x)= 24.53 + 0.6432x
#f(70)=24.53 + 0.6432(70)  y=69.554
#f(75)=24.53 + 0.6432(75)  y=72.77
#f(84)=24.53 + 0.6432(84)  y=78.5588

#interpolacion (esta dentro de los resultados)
#extrapolacion (esta fuera de los resultados) (puede ser mayor o menos que los resultados)

# %%
#11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta
#de regresión ajustada,¿cuáles son los resultados esperados para estos
#tres alumnos?
modelo.predict([1,70])
modelo.predict([1,75])
modelo.predict([1,84])
# Out:
# array([78.55393001])

# %%
#12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y~ X
modelo_lineal=ols("promedio_final~promedio_de_examenes_cortos",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                df       sum_sq      mean_sq          F  \
# promedio_de_examenes_cortos   1.0  1538.228959  1538.228959  38.492412
# Residual                     13.0   519.504375    39.961875        NaN
#
#                                PR(>F)
# promedio_de_examenes_cortos  0.000032
# Residual                          NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "categoria_de_salario":[11,10,8,5,9,7,3,11,8,7,2,9,8,3],
    "ausencias":[18,17,29,36,11,28,35,14,20,32,39,16,31,40]
})
df
# Out:
#     categoria_de_salario  ausencias
# 0                     11         18
# 1                     10         17
# 2                      8         29
# 3                      5         36
# 4                      9         11
# 5                      7         28
# 6                      3         35
# 7                     11         14
# 8                      8         20
# 9                      7         32
# 10                     2         39
# 11                     9         16
# 12                     8         31
# 13                     3         40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   categoria_de_salario  14 non-null     int64
#  1   ausencias             14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
df.describe()
# Out:
#        categoria_de_salario  ausencias
# count             14.000000  14.000000
# mean               7.214286  26.142857
# std                2.939874   9.882830
# min                2.000000  11.000000
# 25%                5.500000  17.250000
# 50%                8.000000  28.500000
# 75%                9.000000  34.250000
# max               11.000000  40.000000

# %%
#1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["categoria_de_salario"]
y=df["ausencias"]

# %%
#2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="ausencias"
plt.title(
    "grafico_de_dispersion_entre_categoria_de_salario y ausencias",
    fontsize=14,
    fontweight="bold"
)
plt.xlabel(
    "categoria_de_salario",
    fontsize=12
)
plt.ylabel(
    "ausencias",
    fontsize=12
)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-182/3990337522.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# 3.¿Los datos soportan la suposición de linealidad?
# Relación lineal negativa fuerte. Se cumple linealidad.

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y)
print(f"coeficiente de correlacion(r):{r:0.4f}"),
print(f"valor-p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion(r):-0.8801
# valor-p:0.0000

# %%
#5. Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinacion:{r**2:0.4f}")
# Out:
# coeficiente de determinacion:0.7746

# %%
#6. obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                   47.487603
# categoria_de_salario    -2.958678
# dtype: float64

# %%
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=1,
label="ausencias"
plt.plot(
    x,y_calculada,
    color="red",
    linewidth=2.2,
    linestyle="-",
    marker="o",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="recta de regresion"
    )
plt.title(
    "grafico_de_dispersion_entre_categoria_de_salario y ausencias",
)
plt.xlabel("categoria_de_salario")
plt.ylabel("ausencias")
plt.legend()
plt.show()

# %%
#7.Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0          1
# const                 39.707750  55.267457
# categoria_de_salario  -3.962455  -1.954900

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales=modelo.resid
#grafico de dispersion
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,residuales)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="residuales"
plt.plot(
    x,residuales,
    marker="o",
    color="red",
    linewidth=0,
    linestyle="",
    markersize=5,
    markerfacecolor="white",
     markeredgecolor="black",
    label="puntos_residuales"
    )
plt.xlabel("categoria_de_salario")
plt.ylabel("residuales")
plt.title("categoria_de_salario_vs_residuales")

plt.axhline(y=0,color="red",linestyle="--")

# %% [markdown]
# Se distribuyen sin patrón claro.
# Se cumplen los supuestos.

# %%
#9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor-p:{valor_p:0.4f}")
# Out:
# valor-p:0.8933

# %% [markdown]
# Valor-p = 0.8933
# cumple con el supuesto de Normalidad.

# %%
#10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.4505

# %% [markdown]
# Valor-p = 0.4505
# cumple con la Homocedasticidad.

# %%
#11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
# Comenta estos resultados.
modelo.predict([1,11])
modelo.predict([1,8])
# Out:
# array([23.81818182])

# %%
#12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal=ols("ausencias~categoria_de_salario",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df      sum_sq     mean_sq          F    PR(>F)
# categoria_de_salario   1.0  983.548996  983.548996  41.243954  0.000033
# Residual              12.0  286.165289   23.847107        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "gastos_generales":[191,170,272,155,280,173,234,116,153,178],
    "unidades":[40,42,53,35,56,39,48,30,37,40]}
)
df
# Out:
#    gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gastos_generales  10 non-null     int64
#  1   unidades          10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#        gastos_generales   unidades
# count         10.000000  10.000000
# mean         192.200000  42.000000
# std           53.349581   8.082904
# min          116.000000  30.000000
# 25%          158.750000  37.500000
# 50%          175.500000  40.000000
# 75%          223.250000  46.500000
# max          280.000000  56.000000

# %%
#1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["gastos_generales"]
y=df["unidades"]

# %%
#2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=10,
label="unidades"
plt.xlabel("gastos_generales")
plt.ylabel("unidades")
plt.title("gastos_generales_vs_unidades")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-182/1358813477.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?
# si

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y)
print(f"coeficiente de correlacion(r):{r:0.4f}"),
print(f"valor-p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion(r):0.9835
# valor-p:0.0000

# %%
#5. Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinacion:{r**2:0.4f}")
# Out:
# coeficiente de determinacion:0.9673

# %%
#6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const               13.360132
# gastos_generales     0.149011
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=10,
label="unidades"
plt.plot(
    x,y_calculada,
    color="red",
    linewidth=2.2,
    linestyle="-",
    marker="o",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="recta de regresion"
    )
plt.xlabel("gastos_generales")
plt.ylabel("unidades")
plt.title("gastos_generales_vs_unidades")
plt.legend()
plt.show()

# %%
#7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                          0          1
# const             8.920794  17.799471
# gastos_generales  0.126675   0.171347

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,residuales)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="residuales"
plt.plot(
    x,residuales,
    marker="o",
    color="red",
    linewidth=0,
    linestyle="",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="puntos_residuales"
    )
plt.xlabel("gastos_generales")
plt.ylabel("residuales")
plt.title("gastos_generales_vs_residuales")
plt.axhline(y=0,color="red",linestyle="--")

# %%
#9.Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor-p:{valor_p:0.4f}")
# Out:
# valor-p:0.3096

# %%
#10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.6267

# %%
#11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
# Comenta estos resultados.
modelo.predict([1,191])
modelo.predict([1,170])
# Out:
# array([38.69196115])

# %%
#12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal=ols("unidades~gastos_generales",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                    df      sum_sq     mean_sq           F        PR(>F)
# gastos_generales  1.0  568.774067  568.774067  236.669535  3.167080e-07
# Residual          8.0   19.225933    2.403242         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "construccion_de_casas":[2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
    "ventas_de_linea_blanca":[5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]
})
df
# Out:
#    construccion_de_casas  ventas_de_linea_blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   construccion_de_casas   10 non-null     float64
#  1   ventas_de_linea_blanca  10 non-null     float64
# dtypes: float64(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#        construccion_de_casas  ventas_de_linea_blanca
# count              10.000000               10.000000
# mean                3.760000                7.550000
# std                 0.977753                1.732211
# min                 2.000000                5.000000
# 25%                 3.300000                6.250000
# 50%                 3.850000                7.450000
# 75%                 4.500000                8.850000
# max                 5.000000               10.000000

# %%
#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["construccion_de_casas"]
y=df["ventas_de_linea_blanca"]

# %%
#2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="ventas_de_linea_blanca"
plt.xlabel("construccion_de_casas")
plt.ylabel("ventas_de_linea_blanca")
plt.title("construccion_de_casas_vs_ventas_de_linea_blanca")
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-182/2204066759.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y)
print(f"coeficiente de correlacion(r):{r:0.4f}"),
print(f"valor-p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion(r):0.9808
# valor-p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinacion:{r**2:0.4f}")
# Out:
# coeficiente de determinacion:0.9619

# %%
#6. obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                    1.016760
# construccion_de_casas    1.737564
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=25,
label="ventas_de_linea_blanca"
plt.plot(
    x,y_calculada,
    color="red",
    linewidth=2.2,
    linestyle="-",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="recta de regresion"
)
plt.xlabel("construccion_de_casas")
plt.ylabel("ventas_de_linea_blanca")
plt.title("construccion_de_casas_vs_ventas_de_linea_blanca")
plt.legend()
plt.show()

# %%
#7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                               0         1
# const                 -0.074848  2.108368
# construccion_de_casas  1.455693  2.019435

# %%
#8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
#¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,residuales)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="residuales"
plt.plot(
    x,residuales,
    marker="o",
    color="red",
    linewidth=0,
    linestyle="",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="puntos_residuales"
    )
plt.xlabel("construccion_de_casas")
plt.ylabel("residuales")
plt.title("construccion_de_casas_vs_residuales")
plt.axhline(y=0,color="red",linestyle="--")

# %%
#9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor-p:{valor_p:0.4f}")
# Out:
# valor-p:0.8464

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.1581

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
# Comenta estos resultados.
modelo.predict([1,2.0])
modelo.predict([1,3.7])
# Out:
# array([7.44574616])

# %%
#12.Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal=ols("ventas_de_linea_blanca~construccion_de_casas",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                         df     sum_sq    mean_sq           F        PR(>F)
# construccion_de_casas  1.0  25.976581  25.976581  202.069951  5.841003e-07
# Residual               8.0   1.028419   0.128552         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
df=pd.DataFrame({
    "numero_interrupciones_al_trabajador":[5,10,10,15,15,20,20,25],
    "calificacion_del_trabajador_en_la_prueba_de_hostilidad":[58,41,45,27,26,12,16,3]
})
df
# Out:
#    numero_interrupciones_al_trabajador  \
# 0                                    5
# 1                                   10
# 2                                   10
# 3                                   15
# 4                                   15
# 5                                   20
# 6                                   20
# 7                                   25
#
#    calificacion_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   numero_interrupciones_al_trabajador                     8 non-null      int64
#  1   calificacion_del_trabajador_en_la_prueba_de_hostilidad  8 non-null      int64
# dtypes: int64(2)
# memory usage: 260.0 bytes

# %%
df.describe()
# Out:
#        numero_interrupciones_al_trabajador  \
# count                             8.000000
# mean                             15.000000
# std                               6.546537
# min                               5.000000
# 25%                              10.000000
# 50%                              15.000000
# 75%                              20.000000
# max                              25.000000
#
#        calificacion_del_trabajador_en_la_prueba_de_hostilidad
# count                                           8.000000
# mean                                           28.500000
# std                                            18.462317
# min                                             3.000000
# 25%                                            15.000000
# 50%                                            26.500000
# 75%                                            42.000000
# max                                            58.000000

# %%
#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x=df["numero_interrupciones_al_trabajador"]
y=df["calificacion_del_trabajador_en_la_prueba_de_hostilidad"]

# %%
#2.Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",

# %% [markdown]
# 3. ¿Los datos soportan la suposición de linealidad?

# %%
#4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, valor_p = pearsonr(x, y)
print(f"coeficiente de correlacion(r):{r:0.4f}"),
print(f"valor-p:{valor_p:0.4f}")
# Out:
# coeficiente de correlacion(r):-0.9928
# valor-p:0.0000

# %%
#5.Calcule el coeficiente de determinación e interprete el resultado.
print(f"coeficiente de determinacion:{r**2:0.4f}")
# Out:
# coeficiente de determinacion:0.9858

# %%
#6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante=sm.add_constant(x)
modelo=sm.OLS(y,x_constante).fit()
y_calculada=modelo.predict(x_constante)
modelo.params
# Out:
# const                                  70.5
# numero_interrupciones_al_trabajador    -2.8
# dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,y)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
label="calificacion_del_trabajador_en_la_prueba_de_hostilidad"
plt.plot(
    x,y_calculada,
    color="red",
    linewidth=2.2,
    linestyle="-",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="recta de regresion"
)
plt.xlabel("numero_interrupciones_al_trabajador")
plt.ylabel("calificacion_del_trabajador_en_la_prueba_de_hostilidad")
plt.title(
    "numero_interrupciones_al_trabajador_vs_calificacion_del_trabajador_en_la_prueba_de_hostilidad"
)
plt.legend()
plt.show()

# %%
#7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
modelo.conf_int(alpha=0.05)
# Out:
#                                              0          1
# const                                65.051384  75.948616
# numero_interrupciones_al_trabajador  -3.136296  -2.463704

# %%
#8.Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales=modelo.resid
plt.figure(
    figsize=(10,6),
    dpi=80
)
plt.scatter(x,residuales)
marker="o",
color="blue",
edgecolor="black",
alpha=0.9,
s=100,
label="residuales"
plt.plot(
    x,residuales,
    marker="o",
    color="red",
    linewidth=0,
    linestyle="",
    markersize=5,
    markerfacecolor="white",
    markeredgecolor="black",
    label="puntos_residuales"
    )
plt.xlabel("numero_interrupciones_al_trabajador")
plt.ylabel("residuales")
plt.title("numero_interrupciones_al_trabajador_vs_residuales")
plt.axhline(y=0,color="red",linestyle="--")

# %%
#9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
estadistico,valor_p=shapiro(residuales)
print(f"valor-p:{valor_p:0.4f}")
# Out:
# valor-p:0.0548

# %%
#10.Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
from statsmodels.stats.api import het_breuschpagan
estadistico_1,valor_p_1,estadistico_2,valor_p_2=het_breuschpagan(residuales,x_constante)
print(f"valor_p:{valor_p_1:0.4f}")
# Out:
# valor_p:0.2482

# %%
#11.Utiliza la recta de regresión para interpolar dos valores y extrapolar uno.
# Comenta estos resultados.
modelo.predict([1,5])
modelo.predict([1,25])
# Out:
# array([0.5])

# %%
#12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
modelo_lineal=ols("numero_interrupciones_al_trabajador ~ calificacion_del_trabajador_en_la_prueba_de_hostilidad",data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#                                                      df      sum_sq  \
# calificacion_del_trabajador_en_la_prueba_de_hos...  1.0  295.725063
# Residual                                            6.0    4.274937
#
#                                                        mean_sq           F  \
# calificacion_del_trabajador_en_la_prueba_de_hos...  295.725063  415.058824
# Residual                                              0.712490         NaN
#
#                                                           PR(>F)
# calificacion_del_trabajador_en_la_prueba_de_hos...  9.090964e-07
# Residual                                                     NaN
